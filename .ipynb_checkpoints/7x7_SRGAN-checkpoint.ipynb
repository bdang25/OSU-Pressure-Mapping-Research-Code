# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load the CSV file
file_path = "soren.csv"  # Ensure this path is correct
data = pd.read_csv(file_path)

# Drop unnecessary columns
data.drop(['Frame', 'Timestamp', 'Average Pressure (mmHg)', 'Minimum Pressure (mmHg)', 
           'Maximum Pressure (mmHg)', 'Standard Pressure Deviation (mmHg)', 
           'Median Pressure (mmHg)', 'Contact Area (m²)', 'Total Area (m²)', 
           'Estimated Force (N)', 'Range Min (mmHg)', 'Range Max (mmHg)'], axis=1, inplace=True)

# Remove rows with all zero values
data = data[(data != 0).any(axis=1)]

# Create a directory to save the images
output_folder = "images_32x32"
os.makedirs(output_folder, exist_ok=True)

# Get the number of rows after filtering
num_rows = data.shape[0]

# Loop through each row in the dataset and save it as a 32x32 image
for i in range(num_rows):
    # Reshape the data into a 32x32 grid
    grid_data = data.iloc[i].values.reshape(32, 32)
    
    # Create a plot without axis
    plt.figure(figsize=(6, 6))
    plt.imshow(grid_data, cmap='viridis', interpolation='none')
    plt.axis('off')  # Remove axis
    
    # Save the image in the output folder
    image_filename = os.path.join(output_folder, f"pressure_image_{i+1}.png")
    plt.savefig(image_filename, bbox_inches='tight', pad_inches=0)
    plt.close()

print(f"Saved {num_rows} images in the '{output_folder}' folder after removing rows with all zero values.")
# Out:
# Saved 510 images in the 'images_32x32' folder after removing rows with all zero values.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load the CSV file
file_path = "soren.csv"  # Ensure this path is correct
data = pd.read_csv(file_path)

# Drop unnecessary columns
data.drop(['Frame', 'Timestamp', 'Average Pressure (mmHg)', 'Minimum Pressure (mmHg)', 
           'Maximum Pressure (mmHg)', 'Standard Pressure Deviation (mmHg)', 
           'Median Pressure (mmHg)', 'Contact Area (m²)', 'Total Area (m²)', 
           'Estimated Force (N)', 'Range Min (mmHg)', 'Range Max (mmHg)'], axis=1, inplace=True)

# Remove rows with all zero values
data = data[(data != 0).any(axis=1)]

# Create a directory to save the 7x7 images
output_folder_7x7 = "images_7x7"
os.makedirs(output_folder_7x7, exist_ok=True)

# Get the number of rows after filtering
num_rows = data.shape[0]

# Loop through each row in the dataset and save it as a 7x7 image
for i in range(num_rows):
    # Reshape the data into a 32x32 grid
    grid_data = data.iloc[i].values.reshape(32, 32)
    
    # Select the values to form a 7x7 grid starting from (2, 2) and taking every 4th square
    selected_indices = [(2 + j * 4, 2 + k * 4) for j in range(7) for k in range(7)]
    reduced_grid_data = np.array([[grid_data[x, y] for x, y in selected_indices[j*7:(j+1)*7]] for j in range(7)])
    
    # Create a plot without axis
    plt.figure(figsize=(4, 4))
    plt.imshow(reduced_grid_data, cmap='viridis', interpolation='none')
    plt.axis('off')  # Remove axis
    
    # Save the image in the output folder
    image_filename_7x7 = os.path.join(output_folder_7x7, f"pressure_image_7x7_{i+1}.png")
    plt.savefig(image_filename_7x7, bbox_inches='tight', pad_inches=0)
    plt.close()

print(f"Saved {num_rows} 7x7 images in the '{output_folder_7x7}' folder after processing the original data.")
# Out:
# Saved 510 7x7 images in the 'images_7x7' folder after processing the original data.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.utils import save_image
import os
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import mean_squared_error as mse

# Define the Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=9, stride=1, padding=4),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 3, kernel_size=9, stride=1, padding=4),
        )

    def forward(self, x):
        return self.model(x)

# Define the Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(512, 1, kernel_size=3, stride=1, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# Prepare Data
def prepare_data(folder_path, image_size=(32, 32)):
    images = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.png'):
            img = plt.imread(os.path.join(folder_path, filename))
            # Ensure the image has 3 channels
            if img.shape[-1] == 4:  # Check for alpha channel
                img = img[..., :3]  # Discard the alpha channel
            img = transforms.ToTensor()(img)
            img = transforms.Resize(image_size)(img)  # Resize to 32x32
            images.append(img)
    return torch.stack(images)

# Paths
folder_7x7 = 'images_7x7'
folder_32x32 = 'images_32x32'
save_models_folder = 'models'
# save_models_folder = 'models'
os.makedirs(save_models_folder, exist_ok=True)

# Load Data
low_res_images = prepare_data(folder_7x7)
high_res_images = prepare_data(folder_32x32)

# Model Setup
generator = Generator()
discriminator = Discriminator()
criterion = nn.BCELoss()
optimizer_G = optim.Adam(generator.parameters(), lr=1e-4)
optimizer_D = optim.Adam(discriminator.parameters(), lr=1e-4)

# Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    for i in range(len(low_res_images)):
        low_res = low_res_images[i].unsqueeze(0)  # Add batch dimension
        high_res = high_res_images[i].unsqueeze(0)

        # Create labels to match the output of the discriminator
        real_label = torch.ones((1, 1, 4, 4))  # Real label (change size to [1, 1, 4, 4])
        fake_label = torch.zeros((1, 1, 4, 4))  # Fake label (change size to [1, 1, 4, 4])

        # Train Discriminator
        optimizer_D.zero_grad()
        outputs = discriminator(high_res)
        d_loss_real = criterion(outputs, real_label)
        d_loss_real.backward()

        fake_image = generator(low_res)
        outputs = discriminator(fake_image.detach())
        d_loss_fake = criterion(outputs, fake_label)
        d_loss_fake.backward()
        optimizer_D.step()

        # Train Generator
        optimizer_G.zero_grad()
        outputs = discriminator(fake_image)
        g_loss = criterion(outputs, real_label)
        g_loss.backward()
        optimizer_G.step()

    print(f'Epoch [{epoch + 1}/{num_epochs}], D Loss: {d_loss_real.item() + d_loss_fake.item():.4f}, G Loss: {g_loss.item():.4f}')
    
    # Save the generator and discriminator models
    torch.save(generator.state_dict(), os.path.join(save_models_folder, 'generator7.pth'))
    torch.save(discriminator.state_dict(), os.path.join(save_models_folder, 'discriminator7.pth'))
# Out:
# Epoch [1/100], D Loss: 1.4333, G Loss: 1.2185
# Epoch [2/100], D Loss: 1.4591, G Loss: 0.6212
# Epoch [3/100], D Loss: 0.5364, G Loss: 1.6386
# Epoch [4/100], D Loss: 0.8873, G Loss: 1.1632
# Epoch [5/100], D Loss: 1.6041, G Loss: 0.6882
# Epoch [6/100], D Loss: 1.0030, G Loss: 1.0672
# Epoch [7/100], D Loss: 0.7592, G Loss: 1.4461
# Epoch [8/100], D Loss: 1.1382, G Loss: 1.0565
# Epoch [9/100], D Loss: 0.7977, G Loss: 1.5030
# Epoch [10/100], D Loss: 0.7530, G Loss: 2.6084
# Epoch [11/100], D Loss: 1.4759, G Loss: 1.1510
# Epoch [12/100], D Loss: 0.4050, G Loss: 2.7244
# Epoch [13/100], D Loss: 1.8778, G Loss: 1.7640
# Epoch [14/100], D Loss: 0.5329, G Loss: 1.8878
# Epoch [15/100], D Loss: 1.3957, G Loss: 3.4794
# Epoch [16/100], D Loss: 1.8283, G Loss: 3.2339
# Epoch [17/100], D Loss: 2.8932, G Loss: 0.6825
# Epoch [18/100], D Loss: 1.0995, G Loss: 1.9715
# Epoch [19/100], D Loss: 0.5739, G Loss: 3.0037
# Epoch [20/100], D Loss: 0.4067, G Loss: 2.6639
# Epoch [21/100], D Loss: 1.7647, G Loss: 0.7876
# Epoch [22/100], D Loss: 1.2630, G Loss: 1.4425
# Epoch [23/100], D Loss: 1.1141, G Loss: 1.6821
# Epoch [24/100], D Loss: 1.4175, G Loss: 0.5872
# Epoch [25/100], D Loss: 1.3898, G Loss: 0.6157
# Epoch [26/100], D Loss: 1.2049, G Loss: 0.5990
# Epoch [27/100], D Loss: 1.1875, G Loss: 0.7356
# Epoch [28/100], D Loss: 1.2676, G Loss: 0.5865
# Epoch [29/100], D Loss: 0.9922, G Loss: 0.9683
# Epoch [30/100], D Loss: 1.6496, G Loss: 0.3951
# Epoch [31/100], D Loss: 1.0654, G Loss: 0.9460
# Epoch [32/100], D Loss: 1.0908, G Loss: 0.9161
# Epoch [33/100], D Loss: 2.0494, G Loss: 0.4392
# Epoch [34/100], D Loss: 1.2498, G Loss: 1.1560
# Epoch [35/100], D Loss: 1.2098, G Loss: 1.1445
# Epoch [36/100], D Loss: 2.0760, G Loss: 0.4164
# Epoch [37/100], D Loss: 1.2745, G Loss: 0.9302
# Epoch [38/100], D Loss: 1.1142, G Loss: 1.1963
# Epoch [39/100], D Loss: 1.0348, G Loss: 1.3865
# Epoch [40/100], D Loss: 1.1982, G Loss: 1.1042
# Epoch [41/100], D Loss: 1.1638, G Loss: 1.1131
# Epoch [42/100], D Loss: 1.1470, G Loss: 1.1348
# Epoch [43/100], D Loss: 0.9864, G Loss: 1.0295
# Epoch [44/100], D Loss: 1.1476, G Loss: 1.4225
# Epoch [45/100], D Loss: 1.0714, G Loss: 1.4723
# Epoch [46/100], D Loss: 1.1247, G Loss: 1.1516
# Epoch [47/100], D Loss: 1.3047, G Loss: 0.9698
# Epoch [48/100], D Loss: 0.8721, G Loss: 1.8392
# Epoch [49/100], D Loss: 1.0503, G Loss: 1.1296
# Epoch [50/100], D Loss: 1.2631, G Loss: 1.0031
# Epoch [51/100], D Loss: 1.0030, G Loss: 0.9125
# Epoch [52/100], D Loss: 0.9855, G Loss: 1.0001
# Epoch [53/100], D Loss: 1.0443, G Loss: 1.0919
# Epoch [54/100], D Loss: 1.0027, G Loss: 1.1255
# Epoch [55/100], D Loss: 1.0047, G Loss: 0.9512
# Epoch [56/100], D Loss: 0.9295, G Loss: 1.1133
# Epoch [57/100], D Loss: 0.9631, G Loss: 0.8707
# Epoch [58/100], D Loss: 1.0015, G Loss: 0.8634
# Epoch [59/100], D Loss: 0.9722, G Loss: 0.9557
# Epoch [60/100], D Loss: 1.0021, G Loss: 0.9904
# Epoch [61/100], D Loss: 1.0096, G Loss: 0.9923
# Epoch [62/100], D Loss: 0.8435, G Loss: 1.1619
# Epoch [63/100], D Loss: 0.9878, G Loss: 0.8205
# Epoch [64/100], D Loss: 0.9179, G Loss: 0.8316
# Epoch [65/100], D Loss: 0.8993, G Loss: 0.9760
# Epoch [66/100], D Loss: 0.9825, G Loss: 0.9401
# Epoch [67/100], D Loss: 1.0153, G Loss: 0.8859
# Epoch [68/100], D Loss: 0.8877, G Loss: 0.8922
# Epoch [69/100], D Loss: 0.8597, G Loss: 1.1327
# Epoch [70/100], D Loss: 0.9404, G Loss: 1.0211
# Epoch [71/100], D Loss: 1.3268, G Loss: 0.6597
# Epoch [72/100], D Loss: 0.7854, G Loss: 1.1024
# Epoch [73/100], D Loss: 1.0143, G Loss: 0.7477
# Epoch [74/100], D Loss: 0.8338, G Loss: 0.9521
# Epoch [75/100], D Loss: 1.0594, G Loss: 0.9041
# Epoch [76/100], D Loss: 0.9229, G Loss: 0.9274
# Epoch [77/100], D Loss: 0.8382, G Loss: 1.0728
# Epoch [78/100], D Loss: 0.9855, G Loss: 1.1504
# Epoch [79/100], D Loss: 0.8829, G Loss: 1.0498
# Epoch [80/100], D Loss: 0.7251, G Loss: 1.1073
# Epoch [81/100], D Loss: 1.1511, G Loss: 1.1148
# Epoch [82/100], D Loss: 0.8752, G Loss: 1.0343
# Epoch [83/100], D Loss: 0.9176, G Loss: 0.9676
# Epoch [84/100], D Loss: 0.9271, G Loss: 0.9655
# Epoch [85/100], D Loss: 0.8875, G Loss: 1.0077
# Epoch [86/100], D Loss: 0.7374, G Loss: 1.3290
# Epoch [87/100], D Loss: 0.9260, G Loss: 1.1546
# Epoch [88/100], D Loss: 0.9349, G Loss: 1.2401
# Epoch [89/100], D Loss: 1.0160, G Loss: 0.7307
# Epoch [90/100], D Loss: 0.9025, G Loss: 1.0818
# Epoch [91/100], D Loss: 1.0094, G Loss: 1.0117
# Epoch [92/100], D Loss: 0.6145, G Loss: 1.7583
# Epoch [93/100], D Loss: 0.7961, G Loss: 1.2610
# Epoch [94/100], D Loss: 0.7355, G Loss: 1.3268
# Epoch [95/100], D Loss: 0.7967, G Loss: 1.2195
# Epoch [96/100], D Loss: 1.0028, G Loss: 1.2608
# Epoch [97/100], D Loss: 1.0244, G Loss: 1.0951
# Epoch [98/100], D Loss: 0.8060, G Loss: 1.2778
# Epoch [99/100], D Loss: 0.7928, G Loss: 1.2477
# Epoch [100/100], D Loss: 0.7906, G Loss: 1.3683

# %%
# Function to visualize images
def visualize_images(low_res, generated_high_res, original_high_res, psnr_value, rmse_value):
    import matplotlib.pyplot as plt

    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    axs[0].imshow(low_res.permute(1, 2, 0).numpy())
    axs[0].set_title('Low Resolution Image')
    axs[0].axis('off')

    axs[1].imshow(generated_high_res.permute(1, 2, 0).detach().numpy())
    axs[1].set_title(f'Generated High Res\nPSNR: {psnr_value:.2f}, RMSE: {rmse_value:.2f}')
    axs[1].axis('off')

    axs[2].imshow(original_high_res.permute(1, 2, 0).numpy())
    axs[2].set_title('Original High Res Image')
    axs[2].axis('off')

    plt.tight_layout()
    plt.show()

# Function to evaluate and display images
def evaluate_image(index):
    # Ensure index is within bounds
    if index < 0 or index >= len(low_res_images):
        print("Index out of range. Please select a valid index.")
        return

    # Get the images
    low_res = low_res_images[index].unsqueeze(0)  # Add batch dimension
    original_high_res = high_res_images[index]

    # Generate high-resolution image
    generator.eval()  # Set generator to evaluation mode
    with torch.no_grad():
        generated_high_res = generator(low_res).squeeze(0)  # Remove batch dimension

    # Calculate PSNR and RMSE
    psnr_value = psnr(original_high_res.numpy(), generated_high_res.numpy())
    rmse_value = np.sqrt(mse(original_high_res.numpy(), generated_high_res.numpy()))

    # Visualize images and metrics
    visualize_images(low_res.squeeze(0), generated_high_res, original_high_res, psnr_value, rmse_value)

# Example usage
evaluate_image(460)  # Replace 0 with the desired index
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.01603106..0.70956784].

# %%
import os
import numpy as np
import torch
from PIL import Image

# Function to save the generated high-res images
def save_generated_images(output_folder):
    # Create the folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through all low-res images
    generator.eval()  # Set generator to evaluation mode
    for i, low_res in enumerate(low_res_images):
        # Add batch dimension
        low_res = low_res.unsqueeze(0)

        # Generate high-resolution image
        with torch.no_grad():
            generated_high_res = generator(low_res).squeeze(0)  # Remove batch dimension

        # Convert to NumPy array and scale to 0-255
        generated_image = (generated_high_res.permute(1, 2, 0).detach().numpy() * 255).astype(np.uint8)

        # Convert to PIL image for saving
        pil_image = Image.fromarray(generated_image)

        # Save the image
        image_path = os.path.join(output_folder, f'gen_img_{i+1}.png')
        pil_image.save(image_path)

        print(f"Saved: {image_path}")

# Example usage
output_folder = "generated_7"
save_generated_images(output_folder)
# Out:
# Saved: generated_7\gen_img_1.png
# Saved: generated_7\gen_img_2.png
# Saved: generated_7\gen_img_3.png
# Saved: generated_7\gen_img_4.png
# Saved: generated_7\gen_img_5.png
# Saved: generated_7\gen_img_6.png
# Saved: generated_7\gen_img_7.png
# Saved: generated_7\gen_img_8.png
# Saved: generated_7\gen_img_9.png
# Saved: generated_7\gen_img_10.png
# Saved: generated_7\gen_img_11.png
# Saved: generated_7\gen_img_12.png
# Saved: generated_7\gen_img_13.png
# Saved: generated_7\gen_img_14.png
# Saved: generated_7\gen_img_15.png
# Saved: generated_7\gen_img_16.png
# Saved: generated_7\gen_img_17.png
# Saved: generated_7\gen_img_18.png
# Saved: generated_7\gen_img_19.png
# Saved: generated_7\gen_img_20.png
# Saved: generated_7\gen_img_21.png
# Saved: generated_7\gen_img_22.png
# Saved: generated_7\gen_img_23.png
# Saved: generated_7\gen_img_24.png
# Saved: generated_7\gen_img_25.png
# Saved: generated_7\gen_img_26.png
# Saved: generated_7\gen_img_27.png
# Saved: generated_7\gen_img_28.png
# Saved: generated_7\gen_img_29.png
# Saved: generated_7\gen_img_30.png
# Saved: generated_7\gen_img_31.png
# Saved: generated_7\gen_img_32.png
# Saved: generated_7\gen_img_33.png
# Saved: generated_7\gen_img_34.png
# Saved: generated_7\gen_img_35.png
# Saved: generated_7\gen_img_36.png
# Saved: generated_7\gen_img_37.png
# Saved: generated_7\gen_img_38.png
# Saved: generated_7\gen_img_39.png
# Saved: generated_7\gen_img_40.png
# Saved: generated_7\gen_img_41.png
# Saved: generated_7\gen_img_42.png
# Saved: generated_7\gen_img_43.png
# Saved: generated_7\gen_img_44.png
# Saved: generated_7\gen_img_45.png
# Saved: generated_7\gen_img_46.png
# Saved: generated_7\gen_img_47.png
# Saved: generated_7\gen_img_48.png
# Saved: generated_7\gen_img_49.png
# Saved: generated_7\gen_img_50.png
# Saved: generated_7\gen_img_51.png
# Saved: generated_7\gen_img_52.png
# Saved: generated_7\gen_img_53.png
# Saved: generated_7\gen_img_54.png
# Saved: generated_7\gen_img_55.png
# Saved: generated_7\gen_img_56.png
# Saved: generated_7\gen_img_57.png
# Saved: generated_7\gen_img_58.png
# Saved: generated_7\gen_img_59.png
# Saved: generated_7\gen_img_60.png
# Saved: generated_7\gen_img_61.png
# Saved: generated_7\gen_img_62.png
# Saved: generated_7\gen_img_63.png
# Saved: generated_7\gen_img_64.png
# Saved: generated_7\gen_img_65.png
# Saved: generated_7\gen_img_66.png
# Saved: generated_7\gen_img_67.png
# Saved: generated_7\gen_img_68.png
# Saved: generated_7\gen_img_69.png
# Saved: generated_7\gen_img_70.png
# Saved: generated_7\gen_img_71.png
# Saved: generated_7\gen_img_72.png
# Saved: generated_7\gen_img_73.png
# Saved: generated_7\gen_img_74.png
# Saved: generated_7\gen_img_75.png
# Saved: generated_7\gen_img_76.png
# Saved: generated_7\gen_img_77.png
# Saved: generated_7\gen_img_78.png
# Saved: generated_7\gen_img_79.png
# Saved: generated_7\gen_img_80.png
# Saved: generated_7\gen_img_81.png
# Saved: generated_7\gen_img_82.png
# Saved: generated_7\gen_img_83.png
# Saved: generated_7\gen_img_84.png
# Saved: generated_7\gen_img_85.png
# Saved: generated_7\gen_img_86.png
# Saved: generated_7\gen_img_87.png
# Saved: generated_7\gen_img_88.png
# Saved: generated_7\gen_img_89.png
# Saved: generated_7\gen_img_90.png
# Saved: generated_7\gen_img_91.png
# Saved: generated_7\gen_img_92.png
# Saved: generated_7\gen_img_93.png
# Saved: generated_7\gen_img_94.png
# Saved: generated_7\gen_img_95.png
# Saved: generated_7\gen_img_96.png
# Saved: generated_7\gen_img_97.png
# Saved: generated_7\gen_img_98.png
# Saved: generated_7\gen_img_99.png
# Saved: generated_7\gen_img_100.png
# Saved: generated_7\gen_img_101.png
# Saved: generated_7\gen_img_102.png
# Saved: generated_7\gen_img_103.png
# Saved: generated_7\gen_img_104.png
# Saved: generated_7\gen_img_105.png
# Saved: generated_7\gen_img_106.png
# Saved: generated_7\gen_img_107.png
# Saved: generated_7\gen_img_108.png
# Saved: generated_7\gen_img_109.png
# Saved: generated_7\gen_img_110.png
# Saved: generated_7\gen_img_111.png
# Saved: generated_7\gen_img_112.png
# Saved: generated_7\gen_img_113.png
# Saved: generated_7\gen_img_114.png
# Saved: generated_7\gen_img_115.png
# Saved: generated_7\gen_img_116.png
# Saved: generated_7\gen_img_117.png
# Saved: generated_7\gen_img_118.png
# Saved: generated_7\gen_img_119.png
# Saved: generated_7\gen_img_120.png
# Saved: generated_7\gen_img_121.png
# Saved: generated_7\gen_img_122.png
# Saved: generated_7\gen_img_123.png
# Saved: generated_7\gen_img_124.png
# Saved: generated_7\gen_img_125.png
# Saved: generated_7\gen_img_126.png
# Saved: generated_7\gen_img_127.png
# Saved: generated_7\gen_img_128.png
# Saved: generated_7\gen_img_129.png
# Saved: generated_7\gen_img_130.png
# Saved: generated_7\gen_img_131.png
# Saved: generated_7\gen_img_132.png
# Saved: generated_7\gen_img_133.png
# Saved: generated_7\gen_img_134.png
# Saved: generated_7\gen_img_135.png
# Saved: generated_7\gen_img_136.png
# Saved: generated_7\gen_img_137.png
# Saved: generated_7\gen_img_138.png
# Saved: generated_7\gen_img_139.png
# Saved: generated_7\gen_img_140.png
# Saved: generated_7\gen_img_141.png
# Saved: generated_7\gen_img_142.png
# Saved: generated_7\gen_img_143.png
# Saved: generated_7\gen_img_144.png
# Saved: generated_7\gen_img_145.png
# Saved: generated_7\gen_img_146.png
# Saved: generated_7\gen_img_147.png
# Saved: generated_7\gen_img_148.png
# Saved: generated_7\gen_img_149.png
# Saved: generated_7\gen_img_150.png
# Saved: generated_7\gen_img_151.png
# Saved: generated_7\gen_img_152.png
# Saved: generated_7\gen_img_153.png
# Saved: generated_7\gen_img_154.png
# Saved: generated_7\gen_img_155.png
# Saved: generated_7\gen_img_156.png
# Saved: generated_7\gen_img_157.png
# Saved: generated_7\gen_img_158.png
# Saved: generated_7\gen_img_159.png
# Saved: generated_7\gen_img_160.png
# Saved: generated_7\gen_img_161.png
# Saved: generated_7\gen_img_162.png
# Saved: generated_7\gen_img_163.png
# Saved: generated_7\gen_img_164.png
# Saved: generated_7\gen_img_165.png
# Saved: generated_7\gen_img_166.png
# Saved: generated_7\gen_img_167.png
# Saved: generated_7\gen_img_168.png
# Saved: generated_7\gen_img_169.png
# Saved: generated_7\gen_img_170.png
# Saved: generated_7\gen_img_171.png
# Saved: generated_7\gen_img_172.png
# Saved: generated_7\gen_img_173.png
# Saved: generated_7\gen_img_174.png
# Saved: generated_7\gen_img_175.png
# Saved: generated_7\gen_img_176.png
# Saved: generated_7\gen_img_177.png
# Saved: generated_7\gen_img_178.png
# Saved: generated_7\gen_img_179.png
# Saved: generated_7\gen_img_180.png
# Saved: generated_7\gen_img_181.png
# Saved: generated_7\gen_img_182.png
# Saved: generated_7\gen_img_183.png
# Saved: generated_7\gen_img_184.png
# Saved: generated_7\gen_img_185.png
# Saved: generated_7\gen_img_186.png
# Saved: generated_7\gen_img_187.png
# Saved: generated_7\gen_img_188.png
# Saved: generated_7\gen_img_189.png
# Saved: generated_7\gen_img_190.png
# Saved: generated_7\gen_img_191.png
# Saved: generated_7\gen_img_192.png
# Saved: generated_7\gen_img_193.png
# Saved: generated_7\gen_img_194.png
# Saved: generated_7\gen_img_195.png
# Saved: generated_7\gen_img_196.png
# Saved: generated_7\gen_img_197.png
# Saved: generated_7\gen_img_198.png
# Saved: generated_7\gen_img_199.png
# Saved: generated_7\gen_img_200.png
# Saved: generated_7\gen_img_201.png
# Saved: generated_7\gen_img_202.png
# Saved: generated_7\gen_img_203.png
# Saved: generated_7\gen_img_204.png
# Saved: generated_7\gen_img_205.png
# Saved: generated_7\gen_img_206.png
# Saved: generated_7\gen_img_207.png
# Saved: generated_7\gen_img_208.png
# Saved: generated_7\gen_img_209.png
# Saved: generated_7\gen_img_210.png
# Saved: generated_7\gen_img_211.png
# Saved: generated_7\gen_img_212.png
# Saved: generated_7\gen_img_213.png
# Saved: generated_7\gen_img_214.png
# Saved: generated_7\gen_img_215.png
# Saved: generated_7\gen_img_216.png
# Saved: generated_7\gen_img_217.png
# Saved: generated_7\gen_img_218.png
# Saved: generated_7\gen_img_219.png
# Saved: generated_7\gen_img_220.png
# Saved: generated_7\gen_img_221.png
# Saved: generated_7\gen_img_222.png
# Saved: generated_7\gen_img_223.png
# Saved: generated_7\gen_img_224.png
# Saved: generated_7\gen_img_225.png
# Saved: generated_7\gen_img_226.png
# Saved: generated_7\gen_img_227.png
# Saved: generated_7\gen_img_228.png
# Saved: generated_7\gen_img_229.png
# Saved: generated_7\gen_img_230.png
# Saved: generated_7\gen_img_231.png
# Saved: generated_7\gen_img_232.png
# Saved: generated_7\gen_img_233.png
# Saved: generated_7\gen_img_234.png
# Saved: generated_7\gen_img_235.png
# Saved: generated_7\gen_img_236.png
# Saved: generated_7\gen_img_237.png
# Saved: generated_7\gen_img_238.png
# Saved: generated_7\gen_img_239.png
# Saved: generated_7\gen_img_240.png
# Saved: generated_7\gen_img_241.png
# Saved: generated_7\gen_img_242.png
# Saved: generated_7\gen_img_243.png
# Saved: generated_7\gen_img_244.png
# Saved: generated_7\gen_img_245.png
# Saved: generated_7\gen_img_246.png
# Saved: generated_7\gen_img_247.png
# Saved: generated_7\gen_img_248.png
# Saved: generated_7\gen_img_249.png
# Saved: generated_7\gen_img_250.png
# Saved: generated_7\gen_img_251.png
# Saved: generated_7\gen_img_252.png
# Saved: generated_7\gen_img_253.png
# Saved: generated_7\gen_img_254.png
# Saved: generated_7\gen_img_255.png
# Saved: generated_7\gen_img_256.png
# Saved: generated_7\gen_img_257.png
# Saved: generated_7\gen_img_258.png
# Saved: generated_7\gen_img_259.png
# Saved: generated_7\gen_img_260.png
# Saved: generated_7\gen_img_261.png
# Saved: generated_7\gen_img_262.png
# Saved: generated_7\gen_img_263.png
# Saved: generated_7\gen_img_264.png
# Saved: generated_7\gen_img_265.png
# Saved: generated_7\gen_img_266.png
# Saved: generated_7\gen_img_267.png
# Saved: generated_7\gen_img_268.png
# Saved: generated_7\gen_img_269.png
# Saved: generated_7\gen_img_270.png
# Saved: generated_7\gen_img_271.png
# Saved: generated_7\gen_img_272.png
# Saved: generated_7\gen_img_273.png
# Saved: generated_7\gen_img_274.png
# Saved: generated_7\gen_img_275.png
# Saved: generated_7\gen_img_276.png
# Saved: generated_7\gen_img_277.png
# Saved: generated_7\gen_img_278.png
# Saved: generated_7\gen_img_279.png
# Saved: generated_7\gen_img_280.png
# Saved: generated_7\gen_img_281.png
# Saved: generated_7\gen_img_282.png
# Saved: generated_7\gen_img_283.png
# Saved: generated_7\gen_img_284.png
# Saved: generated_7\gen_img_285.png
# Saved: generated_7\gen_img_286.png
# Saved: generated_7\gen_img_287.png
# Saved: generated_7\gen_img_288.png
# Saved: generated_7\gen_img_289.png
# Saved: generated_7\gen_img_290.png
# Saved: generated_7\gen_img_291.png
# Saved: generated_7\gen_img_292.png
# Saved: generated_7\gen_img_293.png
# Saved: generated_7\gen_img_294.png
# Saved: generated_7\gen_img_295.png
# Saved: generated_7\gen_img_296.png
# Saved: generated_7\gen_img_297.png
# Saved: generated_7\gen_img_298.png
# Saved: generated_7\gen_img_299.png
# Saved: generated_7\gen_img_300.png
# Saved: generated_7\gen_img_301.png
# Saved: generated_7\gen_img_302.png
# Saved: generated_7\gen_img_303.png
# Saved: generated_7\gen_img_304.png
# Saved: generated_7\gen_img_305.png
# Saved: generated_7\gen_img_306.png
# Saved: generated_7\gen_img_307.png
# Saved: generated_7\gen_img_308.png
# Saved: generated_7\gen_img_309.png
# Saved: generated_7\gen_img_310.png
# Saved: generated_7\gen_img_311.png
# Saved: generated_7\gen_img_312.png
# Saved: generated_7\gen_img_313.png
# Saved: generated_7\gen_img_314.png
# Saved: generated_7\gen_img_315.png
# Saved: generated_7\gen_img_316.png
# Saved: generated_7\gen_img_317.png
# Saved: generated_7\gen_img_318.png
# Saved: generated_7\gen_img_319.png
# Saved: generated_7\gen_img_320.png
# Saved: generated_7\gen_img_321.png
# Saved: generated_7\gen_img_322.png
# Saved: generated_7\gen_img_323.png
# Saved: generated_7\gen_img_324.png
# Saved: generated_7\gen_img_325.png
# Saved: generated_7\gen_img_326.png
# Saved: generated_7\gen_img_327.png
# Saved: generated_7\gen_img_328.png
# Saved: generated_7\gen_img_329.png
# Saved: generated_7\gen_img_330.png
# Saved: generated_7\gen_img_331.png
# Saved: generated_7\gen_img_332.png
# Saved: generated_7\gen_img_333.png
# Saved: generated_7\gen_img_334.png
# Saved: generated_7\gen_img_335.png
# Saved: generated_7\gen_img_336.png
# Saved: generated_7\gen_img_337.png
# Saved: generated_7\gen_img_338.png
# Saved: generated_7\gen_img_339.png
# Saved: generated_7\gen_img_340.png
# Saved: generated_7\gen_img_341.png
# Saved: generated_7\gen_img_342.png
# Saved: generated_7\gen_img_343.png
# Saved: generated_7\gen_img_344.png
# Saved: generated_7\gen_img_345.png
# Saved: generated_7\gen_img_346.png
# Saved: generated_7\gen_img_347.png
# Saved: generated_7\gen_img_348.png
# Saved: generated_7\gen_img_349.png
# Saved: generated_7\gen_img_350.png
# Saved: generated_7\gen_img_351.png
# Saved: generated_7\gen_img_352.png
# Saved: generated_7\gen_img_353.png
# Saved: generated_7\gen_img_354.png
# Saved: generated_7\gen_img_355.png
# Saved: generated_7\gen_img_356.png
# Saved: generated_7\gen_img_357.png
# Saved: generated_7\gen_img_358.png
# Saved: generated_7\gen_img_359.png
# Saved: generated_7\gen_img_360.png
# Saved: generated_7\gen_img_361.png
# Saved: generated_7\gen_img_362.png
# Saved: generated_7\gen_img_363.png
# Saved: generated_7\gen_img_364.png
# Saved: generated_7\gen_img_365.png
# Saved: generated_7\gen_img_366.png
# Saved: generated_7\gen_img_367.png
# Saved: generated_7\gen_img_368.png
# Saved: generated_7\gen_img_369.png
# Saved: generated_7\gen_img_370.png
# Saved: generated_7\gen_img_371.png
# Saved: generated_7\gen_img_372.png
# Saved: generated_7\gen_img_373.png
# Saved: generated_7\gen_img_374.png
# Saved: generated_7\gen_img_375.png
# Saved: generated_7\gen_img_376.png
# Saved: generated_7\gen_img_377.png
# Saved: generated_7\gen_img_378.png
# Saved: generated_7\gen_img_379.png
# Saved: generated_7\gen_img_380.png
# Saved: generated_7\gen_img_381.png
# Saved: generated_7\gen_img_382.png
# Saved: generated_7\gen_img_383.png
# Saved: generated_7\gen_img_384.png
# Saved: generated_7\gen_img_385.png
# Saved: generated_7\gen_img_386.png
# Saved: generated_7\gen_img_387.png
# Saved: generated_7\gen_img_388.png
# Saved: generated_7\gen_img_389.png
# Saved: generated_7\gen_img_390.png
# Saved: generated_7\gen_img_391.png
# Saved: generated_7\gen_img_392.png
# Saved: generated_7\gen_img_393.png
# Saved: generated_7\gen_img_394.png
# Saved: generated_7\gen_img_395.png
# Saved: generated_7\gen_img_396.png
# Saved: generated_7\gen_img_397.png
# Saved: generated_7\gen_img_398.png
# Saved: generated_7\gen_img_399.png
# Saved: generated_7\gen_img_400.png
# Saved: generated_7\gen_img_401.png
# Saved: generated_7\gen_img_402.png
# Saved: generated_7\gen_img_403.png
# Saved: generated_7\gen_img_404.png
# Saved: generated_7\gen_img_405.png
# Saved: generated_7\gen_img_406.png
# Saved: generated_7\gen_img_407.png
# Saved: generated_7\gen_img_408.png
# Saved: generated_7\gen_img_409.png
# Saved: generated_7\gen_img_410.png
# Saved: generated_7\gen_img_411.png
# Saved: generated_7\gen_img_412.png
# Saved: generated_7\gen_img_413.png
# Saved: generated_7\gen_img_414.png
# Saved: generated_7\gen_img_415.png
# Saved: generated_7\gen_img_416.png
# Saved: generated_7\gen_img_417.png
# Saved: generated_7\gen_img_418.png
# Saved: generated_7\gen_img_419.png
# Saved: generated_7\gen_img_420.png
# Saved: generated_7\gen_img_421.png
# Saved: generated_7\gen_img_422.png
# Saved: generated_7\gen_img_423.png
# Saved: generated_7\gen_img_424.png
# Saved: generated_7\gen_img_425.png
# Saved: generated_7\gen_img_426.png
# Saved: generated_7\gen_img_427.png
# Saved: generated_7\gen_img_428.png
# Saved: generated_7\gen_img_429.png
# Saved: generated_7\gen_img_430.png
# Saved: generated_7\gen_img_431.png
# Saved: generated_7\gen_img_432.png
# Saved: generated_7\gen_img_433.png
# Saved: generated_7\gen_img_434.png
# Saved: generated_7\gen_img_435.png
# Saved: generated_7\gen_img_436.png
# Saved: generated_7\gen_img_437.png
# Saved: generated_7\gen_img_438.png
# Saved: generated_7\gen_img_439.png
# Saved: generated_7\gen_img_440.png
# Saved: generated_7\gen_img_441.png
# Saved: generated_7\gen_img_442.png
# Saved: generated_7\gen_img_443.png
# Saved: generated_7\gen_img_444.png
# Saved: generated_7\gen_img_445.png
# Saved: generated_7\gen_img_446.png
# Saved: generated_7\gen_img_447.png
# Saved: generated_7\gen_img_448.png
# Saved: generated_7\gen_img_449.png
# Saved: generated_7\gen_img_450.png
# Saved: generated_7\gen_img_451.png
# Saved: generated_7\gen_img_452.png
# Saved: generated_7\gen_img_453.png
# Saved: generated_7\gen_img_454.png
# Saved: generated_7\gen_img_455.png
# Saved: generated_7\gen_img_456.png
# Saved: generated_7\gen_img_457.png
# Saved: generated_7\gen_img_458.png
# Saved: generated_7\gen_img_459.png
# Saved: generated_7\gen_img_460.png
# Saved: generated_7\gen_img_461.png
# Saved: generated_7\gen_img_462.png
# Saved: generated_7\gen_img_463.png
# Saved: generated_7\gen_img_464.png
# Saved: generated_7\gen_img_465.png
# Saved: generated_7\gen_img_466.png
# Saved: generated_7\gen_img_467.png
# Saved: generated_7\gen_img_468.png
# Saved: generated_7\gen_img_469.png
# Saved: generated_7\gen_img_470.png
# Saved: generated_7\gen_img_471.png
# Saved: generated_7\gen_img_472.png
# Saved: generated_7\gen_img_473.png
# Saved: generated_7\gen_img_474.png
# Saved: generated_7\gen_img_475.png
# Saved: generated_7\gen_img_476.png
# Saved: generated_7\gen_img_477.png
# Saved: generated_7\gen_img_478.png
# Saved: generated_7\gen_img_479.png
# Saved: generated_7\gen_img_480.png
# Saved: generated_7\gen_img_481.png
# Saved: generated_7\gen_img_482.png
# Saved: generated_7\gen_img_483.png
# Saved: generated_7\gen_img_484.png
# Saved: generated_7\gen_img_485.png
# Saved: generated_7\gen_img_486.png
# Saved: generated_7\gen_img_487.png
# Saved: generated_7\gen_img_488.png
# Saved: generated_7\gen_img_489.png
# Saved: generated_7\gen_img_490.png
# Saved: generated_7\gen_img_491.png
# Saved: generated_7\gen_img_492.png
# Saved: generated_7\gen_img_493.png
# Saved: generated_7\gen_img_494.png
# Saved: generated_7\gen_img_495.png
# Saved: generated_7\gen_img_496.png
# Saved: generated_7\gen_img_497.png
# Saved: generated_7\gen_img_498.png
# Saved: generated_7\gen_img_499.png
# Saved: generated_7\gen_img_500.png
# Saved: generated_7\gen_img_501.png
# Saved: generated_7\gen_img_502.png
# Saved: generated_7\gen_img_503.png
# Saved: generated_7\gen_img_504.png
# Saved: generated_7\gen_img_505.png
# Saved: generated_7\gen_img_506.png
# Saved: generated_7\gen_img_507.png
# Saved: generated_7\gen_img_508.png
# Saved: generated_7\gen_img_509.png
# Saved: generated_7\gen_img_510.png

# %%
# THIS CODE WILL GIVE YOU REULSTS OF 50 RANDOM IMAGES FROM THE DATASET
# import random
# import numpy as np
# import torch
# import matplotlib.pyplot as plt

# # Function to visualize images
# def visualize_images_with_metrics(low_res, generated_high_res, original_high_res, psnr_value, rmse_value, image_index):
#     fig, axs = plt.subplots(1, 3, figsize=(15, 5))
#     axs[0].imshow(low_res.permute(1, 2, 0).numpy())
#     axs[0].set_title(f'Low Resolution Image\nIndex: {image_index}')
#     axs[0].axis('off')

#     axs[1].imshow(generated_high_res.permute(1, 2, 0).detach().numpy())
#     axs[1].set_title(f'Generated High Res\nPSNR: {psnr_value:.2f}, RMSE: {rmse_value:.2f}')
#     axs[1].axis('off')

#     axs[2].imshow(original_high_res.permute(1, 2, 0).numpy())
#     axs[2].set_title('Original High Res Image')
#     axs[2].axis('off')

#     plt.tight_layout()
#     plt.show()

# # Function to evaluate and display 50 random images
# def evaluate_random_images_and_visualize(num_images):
#     # Ensure the requested number of images does not exceed the dataset size
#     if num_images > len(low_res_images):
#         print(f"Dataset contains only {len(low_res_images)} images. Adjusting to evaluate all available images.")
#         num_images = len(low_res_images)

#     # Randomly select indices
#     random_indices = random.sample(range(len(low_res_images)), num_images)

#     # Loop through the randomly selected indices
#     generator.eval()  # Set generator to evaluation mode
#     for idx in random_indices:
#         low_res = low_res_images[idx].unsqueeze(0)  # Add batch dimension
#         original_high_res = high_res_images[idx]

#         # Generate high-resolution image
#         with torch.no_grad():
#             generated_high_res = generator(low_res).squeeze(0)  # Remove batch dimension

#         # Calculate PSNR and RMSE
#         psnr_value = psnr(original_high_res.numpy(), generated_high_res.numpy())
#         rmse_value = np.sqrt(mse(original_high_res.numpy(), generated_high_res.numpy()))

#         # Visualize the images and metrics
#         visualize_images_with_metrics(
#             low_res.squeeze(0),
#             generated_high_res,
#             original_high_res,
#             psnr_value,
#             rmse_value,
#             idx
#         )

# # Example usage
# evaluate_random_images_and_visualize(50)  # Evaluate and visualize 50 random images

# %%
# Function to evaluate PSNR and RMSE for all images
def evaluate_all_images():
    psnr_values = []
    rmse_values = []

    generator.eval()  # Set generator to evaluation mode
    for i in range(len(low_res_images)):
        low_res = low_res_images[i].unsqueeze(0)  # Add batch dimension
        original_high_res = high_res_images[i]

        # Generate high-resolution image
        with torch.no_grad():
            generated_high_res = generator(low_res).squeeze(0)  # Remove batch dimension

        # Calculate PSNR and RMSE
        psnr_value = psnr(original_high_res.numpy(), generated_high_res.numpy())
        rmse_value = np.sqrt(mse(original_high_res.numpy(), generated_high_res.numpy()))

        # Append metrics to the lists
        psnr_values.append(psnr_value)
        rmse_values.append(rmse_value)

    return psnr_values, rmse_values

# Evaluate metrics for all images
psnr_values_all, rmse_values_all = evaluate_all_images()

import matplotlib.pyplot as plt

# Function to plot PSNR and RMSE with enhanced inbuilt style
def plot_metrics_with_enhanced_style(psnr_values, rmse_values):
    # Use a professional built-in style
    plt.style.use('fivethirtyeight')  # A clean, visually pleasing style

    indices = range(len(psnr_values))  # Image indices

    # Plot PSNR values
    plt.figure(figsize=(14, 7))
    plt.plot(
        indices, psnr_values, label='PSNR (dB)', color='#007acc',
        marker='o', markersize=5, linewidth=2, alpha=0.9
    )
    plt.fill_between(indices, psnr_values, color='#007acc', alpha=0.2)  # Add shading for emphasis
    plt.xlabel('Image Index', fontsize=14, fontweight='bold')
    plt.ylabel('PSNR (dB)', fontsize=14, fontweight='bold')
    plt.title('PSNR vs. Image Index', fontsize=18, fontweight='bold')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
    plt.tight_layout()
    plt.show()

    # Plot RMSE values
    plt.figure(figsize=(14, 7))
    plt.plot(
        indices, rmse_values, label='RMSE', color='#ff5733',
        marker='s', markersize=5, linewidth=2, alpha=0.9
    )
    plt.fill_between(indices, rmse_values, color='#ff5733', alpha=0.2)  # Add shading for emphasis
    plt.xlabel('Image Index', fontsize=14, fontweight='bold')
    plt.ylabel('RMSE', fontsize=14, fontweight='bold')
    plt.title('RMSE vs. Image Index', fontsize=18, fontweight='bold')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
    plt.tight_layout()
    plt.show()

# Example usage
plot_metrics_with_enhanced_style(psnr_values_all, rmse_values_all)
