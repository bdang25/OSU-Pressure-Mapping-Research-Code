# %%
'Hi iam trying to push into github repo'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load the CSV file
file_path = "soren.csv"  # Ensure this path is correct
data = pd.read_csv(file_path)

# Drop unnecessary columns
data.drop(['Frame', 'Timestamp', 'Average Pressure (mmHg)', 'Minimum Pressure (mmHg)', 
           'Maximum Pressure (mmHg)', 'Standard Pressure Deviation (mmHg)', 
           'Median Pressure (mmHg)', 'Contact Area (m²)', 'Total Area (m²)', 
           'Estimated Force (N)', 'Range Min (mmHg)', 'Range Max (mmHg)'], axis=1, inplace=True)

# Remove rows with all zero values
data = data[(data != 0).any(axis=1)]

# Create a directory to save the images
output_folder = "images_32x32"
os.makedirs(output_folder, exist_ok=True)

# Get the number of rows after filtering
num_rows = data.shape[0]

# Loop through each row in the dataset and save it as a 32x32 image
for i in range(num_rows):
    # Reshape the data into a 32x32 grid
    grid_data = data.iloc[i].values.reshape(32, 32)
    
    # Create a plot without axis
    plt.figure(figsize=(6, 6))
    plt.imshow(grid_data, cmap='viridis', interpolation='none')
    plt.axis('off')  # Remove axis
    
    # Save the image in the output folder
    image_filename = os.path.join(output_folder, f"pressure_image_{i+1}.png")
    plt.savefig(image_filename, bbox_inches='tight', pad_inches=0)
    plt.close()

print(f"Saved {num_rows} images in the '{output_folder}' folder after removing rows with all zero values.")
# Out:
# Saved 510 images in the 'images_32x32' folder after removing rows with all zero values.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load the CSV file
file_path = "soren.csv"  # Ensure this path is correct
data = pd.read_csv(file_path)

# Drop unnecessary columns
columns_to_drop = ['Frame', 'Timestamp', 'Average Pressure (mmHg)', 'Minimum Pressure (mmHg)', 
                   'Maximum Pressure (mmHg)', 'Standard Pressure Deviation (mmHg)', 
                   'Median Pressure (mmHg)', 'Contact Area (m²)', 'Total Area (m²)', 
                   'Estimated Force (N)', 'Range Min (mmHg)', 'Range Max (mmHg)']

# Drop metadata columns if they exist
data.drop(columns=[col for col in columns_to_drop if col in data.columns], axis=1, inplace=True)

# Remove rows where all values are zero
data = data[(data != 0).any(axis=1)]

# Create a directory to save the 6x6 images
output_folder_6x6 = "images_6x6"
os.makedirs(output_folder_6x6, exist_ok=True)

# Get the number of rows after filtering
num_rows = data.shape[0]

# Generate 6 evenly spaced indices from a 32×32 grid
indices = np.linspace(2, 30, 6, dtype=int)  # Choosing 6 evenly spaced points in a 32x32 grid

# Generate (x, y) coordinate pairs for the 6×6 grid
selected_indices = [(indices[j], indices[k]) for j in range(6) for k in range(6)]

# Loop through each row in the dataset and save it as a 6x6 image
for i in range(num_rows):
    # Reshape the data into a 32x32 grid
    grid_data = data.iloc[i].values.reshape(32, 32)
    
    # Extract the 6x6 grid correctly
    reduced_grid_data = np.array([
        [grid_data[x, y] for y in np.linspace(2, 30, 6, dtype=int)]  # Select columns
        for x in np.linspace(2, 30, 6, dtype=int)  # Select rows
    ])
    
    # Create a plot without axis
    plt.figure(figsize=(4, 4))
    plt.imshow(reduced_grid_data, cmap='viridis', interpolation='none')
    plt.axis('off')  # Remove axis
    
    # Save the image in the output folder
    image_filename_6x6 = os.path.join(output_folder_6x6, f"pressure_image_6x6_{i+1}.png")
    plt.savefig(image_filename_6x6, bbox_inches='tight', pad_inches=0)
    plt.close()

print(f"Saved {num_rows} 6x6 images in the '{output_folder_6x6}' folder after processing the original data.")
# Out:
# Saved 510 6x6 images in the 'images_6x6' folder after processing the original data.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.models import vgg16, VGG16_Weights
from PIL import Image
import torch.nn.functional as F
import pytorch_msssim  # For SSIM loss

# ===========================
# Device Setup
# ===========================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ===========================
# Generator Model
# ===========================
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Conv2d(channels, channels, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(channels, channels, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(channels),
        )

    def forward(self, x):
        return x + self.block(x)

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.initial = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
        )

        self.residuals = nn.Sequential(
            ResidualBlock(64),
            ResidualBlock(64),
            ResidualBlock(64),
            ResidualBlock(64),
        )

        self.upsampling = nn.Sequential(
    nn.ConvTranspose2d(64, 128, kernel_size=4, stride=2, padding=1),  # 6x6 → 12x12
    nn.BatchNorm2d(128),
    nn.ReLU(inplace=True),

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),  # 12x12 → 24x24
    nn.BatchNorm2d(64),
    nn.ReLU(inplace=True),

    nn.ConvTranspose2d(64, 32, kernel_size=3, stride=1, padding=1),   # 24x24 → 24x24
    nn.BatchNorm2d(32),
    nn.ReLU(inplace=True),

    # 🔥 Upsample 24x24 → 32x32
    nn.Upsample(size=(32, 32), mode='bilinear', align_corners=True),

    nn.Conv2d(32, 3, kernel_size=3, stride=1, padding=1),
    nn.Tanh()
)


    def forward(self, x):
        x = self.initial(x)
        x = self.residuals(x)
        x = self.upsampling(x)
        return x
    
# ===========================
# Discriminator Model
# ===========================
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(512, 1, kernel_size=3, stride=1, padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# ===========================
# Loss Functions
# ===========================
criterion = nn.BCELoss()

def perceptual_loss(generated, target):
    vgg = vgg16(weights=VGG16_Weights.IMAGENET1K_V1).features[:16].to(device)
    for param in vgg.parameters():
        param.requires_grad = False

    resize = nn.Upsample(size=(224, 224), mode='bilinear', align_corners=True)
    return F.mse_loss(vgg(resize(generated)), vgg(resize(target)))

def laplacian_loss(generated, target):
    laplacian_kernel = torch.tensor([[0, -1, 0], [-1, 4, -1], [0, -1, 0]], dtype=torch.float32)
    laplacian_kernel = laplacian_kernel.unsqueeze(0).unsqueeze(0).to(generated.device)
    laplacian_kernel = laplacian_kernel.repeat(3, 1, 1, 1)

    gen_edges = F.conv2d(generated, laplacian_kernel, padding=1, groups=3)
    target_edges = F.conv2d(target, laplacian_kernel, padding=1, groups=3)

    return F.l1_loss(gen_edges, target_edges)

def adaptive_d_loss(d_real, d_fake, epoch, total_epochs):
    alpha = max(0.1, 1 - (epoch / total_epochs))
    return alpha * d_real + alpha * d_fake

# ===========================
# Data Preparation
# ===========================
def prepare_augmented_low_res(folder_path):
    images = []
    transform = transforms.Compose([
        transforms.Resize((6, 6), interpolation=Image.BICUBIC),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomRotation(degrees=10),
        transforms.RandomResizedCrop(6, scale=(0.8, 1.0)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    for filename in os.listdir(folder_path):
        if filename.endswith('.png'):
            img = Image.open(os.path.join(folder_path, filename)).convert("RGB")
            img = transform(img)
            images.append(img)
    return torch.stack(images)

def prepare_images(folder_path, size):
    images = []
    transform = transforms.Compose([
        transforms.Resize(size, interpolation=Image.BICUBIC),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    for filename in os.listdir(folder_path):
        if filename.endswith('.png'):
            img = Image.open(os.path.join(folder_path, filename)).convert("RGB")
            img = transform(img)
            images.append(img)
    return torch.stack(images)

low_res_images = prepare_augmented_low_res('images_6x6').to(device)
high_res_images = prepare_images('images_32x32', (32, 32)).to(device)

# ===========================
# Training Setup
# ===========================
generator = Generator().to(device)
discriminator = Discriminator().to(device)

optimizer_G = optim.Adam(generator.parameters(), lr=5e-5, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=2e-5, betas=(0.5, 0.999))


# ===========================
# 🧪 Step 1 & 2: Sanity Check Generator Output Shape
# ===========================
with torch.no_grad():
    sample_input = torch.randn(1, 3, 6, 6).to(device)
    sample_output = generator(sample_input)
    print("🧪 Generator test output shape:", sample_output.shape)


# ===========================
# Training Loop
# ===========================
num_epochs = 300
batch_size = 4

for epoch in range(num_epochs):
    for i in range(0, len(low_res_images), batch_size):
        low_res = low_res_images[i:i+batch_size].to(device)
        high_res = high_res_images[i:i+batch_size].to(device)

        # Train Discriminator
        optimizer_D.zero_grad()
        real_output = discriminator(high_res).view(-1)
        d_loss_real = criterion(real_output, torch.ones_like(real_output).to(device))

        fake_image = generator(low_res)
        fake_output = discriminator(fake_image.detach()).view(-1)
        d_loss_fake = criterion(fake_output, torch.zeros_like(fake_output).to(device))

        d_loss = adaptive_d_loss(d_loss_real, d_loss_fake, epoch, num_epochs)
        d_loss.backward()
        optimizer_D.step()

        # Train Generator
        optimizer_G.zero_grad()
        fake_image = generator(low_res)
        fake_output = discriminator(fake_image).view(-1)

        g_bce_loss = criterion(fake_output, torch.ones_like(fake_output).to(device))
        g_percep_loss = perceptual_loss(fake_image, high_res)
        g_lap_loss = laplacian_loss(fake_image, high_res)

        perceptual_weight = 0.2 + (epoch / num_epochs) * 0.2
        edge_weight = 0.2 - (epoch / num_epochs) * 0.1

        g_loss = g_bce_loss + perceptual_weight * g_percep_loss + edge_weight * g_lap_loss
        g_loss.backward()
        optimizer_G.step()

    print(f"Epoch [{epoch+1}/{num_epochs}], D Loss: {d_loss.item():.4f}, G Loss: {g_loss.item():.4f}")

    if (epoch + 1) % 50 == 0:
        os.makedirs("models", exist_ok=True)
        torch.save(generator.state_dict(), f"models/generator_epoch{epoch+1}.pth")
        torch.save(discriminator.state_dict(), f"models/discriminator_epoch{epoch+1}.pth")
        print(f"✅ Checkpoint saved at epoch {epoch+1}")

# ===========================
# Save Final Models
# ===========================
os.makedirs("models", exist_ok=True)
torch.save(generator.state_dict(), "models/generatorN.pth")
torch.save(discriminator.state_dict(), "models/discriminatorN.pth")
print("✅ Final models saved as generatorN.pth and discriminatorN.pth")

# ===========================
# Export to ONNX
# ===========================
print("📦 Exporting Generator to ONNX format...")

# Create a dummy input of the correct shape (batch_size=1, channels=3, height=6, width=6)
dummy_input = torch.randn(1, 3, 6, 6).to(device)

# Export the model
torch.onnx.export(
    generator,                         # Model
    dummy_input,                       # Example input
    "models/generator.onnx",          # File path
    export_params=True,
    opset_version=11,
    do_constant_folding=True,
    input_names=['input'],
    output_names=['output'],
    dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'
# Epoch [271/300], D Loss: 0.0599, G Loss: 1.3328
# Epoch [272/300], D Loss: 0.0211, G Loss: 2.6036
# Epoch [273/300], D Loss: 0.0221, G Loss: 2.1803
# Epoch [274/300], D Loss: 0.0572, G Loss: 1.1853
# Epoch [275/300], D Loss: 0.0322, G Loss: 1.9549
# Epoch [276/300], D Loss: 0.0572, G Loss: 1.5448
# Epoch [277/300], D Loss: 0.1223, G Loss: 2.0197
# Epoch [278/300], D Loss: 0.1327, G Loss: 0.8058
# Epoch [279/300], D Loss: 0.0868, G Loss: 1.2213
# Epoch [280/300], D Loss: 0.0359, G Loss: 2.1989
# Epoch [281/300], D Loss: 0.0275, G Loss: 2.7748
# Epoch [282/300], D Loss: 0.0709, G Loss: 1.3903
# Epoch [283/300], D Loss: 0.0405, G Loss: 2.1554
# Epoch [284/300], D Loss: 0.0185, G Loss: 2.9198
# Epoch [285/300], D Loss: 0.0921, G Loss: 1.4234
# Epoch [286/300], D Loss: 0.0178, G Loss: 3.0875
# Epoch [287/300], D Loss: 0.0405, G Loss: 1.8326
# Epoch [288/300], D Loss: 0.0949, G Loss: 0.8619
# Epoch [289/300], D Loss: 0.0184, G Loss: 2.8667
# Epoch [290/300], D Loss: 0.0242, G Loss: 2.8334
# Epoch [291/300], D Loss: 0.0222, G Loss: 3.5847
# Epoch [292/300], D Loss: 0.0236, G Loss: 3.2356
# Epoch [293/300], D Loss: 0.0402, G Loss: 2.1178
# Epoch [294/300], D Loss: 0.1319, G Loss: 1.5989
# Epoch [295/300], D Loss: 0.0085, G Loss: 3.2779
# Epoch [296/300], D Loss: 0.0916, G Loss: 0.9113
# Epoch [297/300], D Loss: 0.1065, G Loss: 2.2113
# Epoch [298/300], D Loss: 0.0180, G Loss: 2.9211
# Epoch [299/300], D Loss: 0.0926, G Loss: 1.1269
# Epoch [300/300], D Loss: 0.0638, G Loss: 1.2295
# ✅ Checkpoint saved at epoch 300
# ✅ Final models saved as generatorN.pth and discriminatorN.pth
# 📦 Exporting Generator to ONNX format...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/PressureSensing/PressureSensing/venv/lib/python3.12/site-packages/torch/onnx/_internal/onnx_proto_utils.py:181, in _add_onnxscript_fn(model_bytes, custom_opsets)
#     180 try:
# --> 181     import onnx
#     182 except ImportError as e:
#
# ModuleNotFoundError: No module named 'onnx'
#
# The above exception was the direct cause of the following exception:
#
# OnnxExporterError                         Traceback (most recent call last)
# Cell In[7], line 254
#     251 dummy_input = torch.randn(1, 3, 6, 6).to(device)
#     253 # Export the model
# --> 254 torch.onnx.export(
#     255     generator,                         # Model
#     256     dummy_input,                       # Example input
#     257     "models/generator.onnx",          # File path
#     258     export_params=True,
#     259     opset_version=11,
#     260     do_constant_folding=True,
#     261     input_names=['input'],
#     262     output_names=['output'],
#     263     dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}
#     264 )
#     266 print("✅ ONNX model exported successfully to models/generator.onnx")
#
# File ~/Desktop/PressureSensing/PressureSensing/venv/lib/python3.12/site-packages/torch/onnx/__init__.py:383, in export(model, args, f, kwargs, export_params, verbose, input_names, output_names, opset_version, dynamic_axes, keep_initializers_as_inputs, dynamo, external_data, dynamic_shapes, custom_translation_table, report, optimize, verify, profile, dump_exported_program, artifacts_dir, fallback, training, operator_export_type, do_constant_folding, custom_opsets, export_modules_as_functions, autograd_inlining, **_)
#     377 if dynamic_shapes:
#     378     raise ValueError(
#     379         "The exporter only supports dynamic shapes "
#     380         "through parameter dynamic_axes when dynamo=False."
#     381     )
# --> 383 export(
#     384     model,
#     385     args,
#     386     f,  # type: ignore[arg-type]
#     387     kwargs=kwargs,
#     388     export_params=export_params,
#     389     verbose=verbose is True,
#     390     input_names=input_names,
#     391     output_names=output_names,
#     392     opset_version=opset_version,
#     393     dynamic_axes=dynamic_axes,
#     394     keep_initializers_as_inputs=keep_initializers_as_inputs,
#     395     training=training,
#     396     operator_export_type=operator_export_type,
#     397     do_constant_folding=do_constant_folding,
#     398     custom_opsets=custom_opsets,
#     399     export_modules_as_functions=export_modules_as_functions,
#     400     autograd_inlining=autograd_inlining,
#     401 )
#     402 return None
#
# File ~/Desktop/PressureSensing/PressureSensing/venv/lib/python3.12/site-packages/torch/onnx/utils.py:495, in export(model, args, f, kwargs, export_params, verbose, training, input_names, output_names, operator_export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, custom_opsets, export_modules_as_functions, autograd_inlining)
#     492 if kwargs is not None:
#     493     args = args + (kwargs,)
# --> 495 _export(
#     496     model,
#     497     args,
#     498     f,
#     499     export_params,
#     500     verbose,
#     501     training,
#     502     input_names,
#     503     output_names,
#     504     operator_export_type=operator_export_type,
#     505     opset_version=opset_version,
#     506     do_constant_folding=do_constant_folding,
#     507     dynamic_axes=dynamic_axes,
#     508     keep_initializers_as_inputs=keep_initializers_as_inputs,
#     509     custom_opsets=custom_opsets,
#     510     export_modules_as_functions=export_modules_as_functions,
#     511     autograd_inlining=autograd_inlining,
#     512 )
#     514 return None
#
# File ~/Desktop/PressureSensing/PressureSensing/venv/lib/python3.12/site-packages/torch/onnx/utils.py:1501, in _export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, fixed_batch_size, custom_opsets, add_node_names, onnx_shape_inference, export_modules_as_functions, autograd_inlining)
#    1482     (
#    1483         proto,
#    1484         export_map,
#    (...)
#    1498         node_attr_to_name,
#    1499     )
#    1500 # insert function_proto into model_proto.
# -> 1501 proto = onnx_proto_utils._add_onnxscript_fn(
#    1502     proto,
#    1503     custom_opsets,
#    1504 )
#    1505 if verbose:
#    1506     _C._jit_onnx_log("Exported graph: ", graph)
#
# File ~/Desktop/PressureSensing/PressureSensing/venv/lib/python3.12/site-packages/torch/onnx/_internal/onnx_proto_utils.py:183, in _add_onnxscript_fn(model_bytes, custom_opsets)
#     181     import onnx
#     182 except ImportError as e:
# --> 183     raise errors.OnnxExporterError("Module onnx is not installed!") from e
#     185 # For > 2GB model, onnx.load_fromstring would fail. However, because
#     186 # in _export_onnx, the tensors should be saved separately if the proto
#     187 # size > 2GB, and if it for some reason did not, the model would fail on
#     188 # serialization anyway in terms of the protobuf limitation. So we don't
#     189 # need to worry about > 2GB model getting here.
#     190 model_proto = onnx.load_model_from_string(model_bytes)  # type: ignore[attr-defined]
#
# OnnxExporterError: Module onnx is not installed!

# %%
import os
import torch
from PIL import Image
import torchvision.transforms as transforms

# Make sure to define or import your Generator class before using it
# from your_model_file import Generator

# Load Trained Generator
generator = Generator()
generator.load_state_dict(torch.load("models/generatorN.pth"))
generator.eval()

# Define folders
input_folder = "images_6x6"
output_folder = "upscaled_250N_32x32"
os.makedirs(output_folder, exist_ok=True)

# Correct Transformations for low-res image
transform = transforms.Compose([
    transforms.Resize((6, 6)),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])  # Match training normalization
])

# Process images and save with new file names
for i, filename in enumerate(os.listdir(input_folder), start=1):
    if filename.endswith(".png"):
        input_path = os.path.join(input_folder, filename)

        # Load and preprocess the image
        test_image = Image.open(input_path).convert("RGB")
        low_res_input = transform(test_image).unsqueeze(0)  # Add batch dimension

        # Generate upscaled 32×32 image
        with torch.no_grad():
            upscaled_image = generator(low_res_input).squeeze(0)  # Remove batch dimension

            # Convert from [-1, 1] to [0, 1]
            upscaled_image = (upscaled_image + 1) / 2

            # Convert tensor to PIL image
            upscaled_image = transforms.ToPILImage()(upscaled_image)
            
            # Create the new file name following the pattern
            new_filename = f"pressure_image_32x32_{i}.png"
            output_path = os.path.join(output_folder, new_filename)
            
            # Save the upscaled image
            upscaled_image.save(output_path)

        print(f"✅ Upscaled and saved: {output_path}")

print("🚀 All images successfully upscaled to upscaled_250N_32×32 and saved!")
# Out:
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_1.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_2.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_3.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_4.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_5.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_6.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_7.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_8.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_9.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_10.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_11.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_12.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_13.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_14.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_15.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_16.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_17.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_18.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_19.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_20.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_21.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_22.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_23.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_24.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_25.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_26.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_27.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_28.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_29.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_30.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_31.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_32.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_33.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_34.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_35.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_36.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_37.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_38.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_39.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_40.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_41.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_42.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_43.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_44.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_45.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_46.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_47.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_48.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_49.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_50.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_51.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_52.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_53.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_54.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_55.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_56.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_57.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_58.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_59.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_60.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_61.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_62.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_63.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_64.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_65.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_66.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_67.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_68.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_69.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_70.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_71.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_72.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_73.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_74.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_75.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_76.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_77.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_78.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_79.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_80.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_81.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_82.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_83.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_84.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_85.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_86.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_87.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_88.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_89.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_90.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_91.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_92.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_93.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_94.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_95.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_96.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_97.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_98.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_99.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_100.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_101.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_102.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_103.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_104.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_105.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_106.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_107.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_108.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_109.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_110.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_111.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_112.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_113.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_114.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_115.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_116.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_117.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_118.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_119.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_120.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_121.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_122.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_123.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_124.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_125.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_126.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_127.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_128.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_129.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_130.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_131.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_132.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_133.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_134.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_135.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_136.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_137.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_138.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_139.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_140.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_141.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_142.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_143.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_144.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_145.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_146.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_147.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_148.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_149.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_150.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_151.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_152.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32_153.png
# ✅ Upscaled and saved: upscaled_250N_32x32/pressure_image_32x32